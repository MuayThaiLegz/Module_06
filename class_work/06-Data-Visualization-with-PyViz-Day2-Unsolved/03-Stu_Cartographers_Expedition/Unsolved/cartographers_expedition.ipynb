# %% [markdown]
# # A Cartographers Expedition

# %% [markdown]
# You and your friends have decided to tackle NYC old school! No cell phones or GPS devices allowed. Although everyone is a bit nervous,  you realize that using an actual map might be pretty cool.
#
# Your goal is to generate a map that plots your between five and six locations in the city.  Plotly Express and Mapbox should be used to plot the route (point A to point B to point C) for the expedition.

# %% [markdown]
# ## Import the required libraries and dependencies

# %%
import pandas as pd
import plotly.express as px
import os
from pathlib import Path
from dotenv import load_dotenv

# %% [markdown]
# ## Step 1: Create a .env file to hold your Mapbox API Access Token

# %% [markdown]
# ## Step 2: Read in the Mapbox API access token using the `os.getenv` function. Use the function provided to confirm that the token is available for use in the program. Finally, set your Mapbox API access token as the parameter in the `px.set_mapbox_access_token` function.

# %%
# Set up API credentials
# Read the Mapbox API access token
# YOUR CODE HERE
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 1
# True

# %%
map_box_api_access_token = os.getenv("MAPBOX_API_ACCESS_TOKEN")

# %%
# Confirm that the mapbox_api_access_token is available
type(map_box_api_access_token)
# Out:
# str

# %%
# Set the Mapbox API access token
# YOUR CODE HERE
px.set_mapbox_access_token(map_box_api_access_token)

# %%
type('map_box_api_access_token')
# Out:
# str

# %% [markdown]
# ## Step 3: Read in the `nyc_excursion_plans.csv` file in to a Pandas DataFrame. Drop any rows that contain missing data or NaN values.

# %%
# Read the the ny_places_interest.csv file into a DataFrame
places_of_interest_cool = pd.read_csv(
    Path('../Resources/nyc_excursion_plans.csv')
).dropna()

# Review the DataFrame
# YOUR CODE HERE

display(places_of_interest_cool.head())
# Out:
#    Id  Longitude   Latitude                Name PlaceType Borough
# 0  90 -73.888958  40.896210  Van Cortlandt Park      Park   Bronx
# 1  95 -73.871651  40.889879   Woodlawn Cemetery  Cemetery   Bronx
# 2  81 -73.838642  40.886965    Seton Falls Park      Park   Bronx
# 3  69 -73.809802  40.877986     Pelham Bay Park      Park   Bronx
# 4   8 -73.878308  40.864424    Botanical Garden    Garden   Bronx

# %%
display(places_of_interest_cool.tail())
# Out:
#     Id  Longitude   Latitude  \
# 90  73 -74.005553  40.672047
# 91  80 -73.898472  40.764449
# 92  75 -73.916829  40.892306
# 94  87 -73.865019  40.645828
# 95  86 -73.844211  40.646316
#
#                                                  Name PlaceType   Borough
# 90                                      Red Hook Park      Park  Brooklyn
# 91                           Saint Michael's Cemetery  Cemetery    Queens
# 92                                     Riverdale Park      Park     Bronx
# 94               Spring Creek Park Preserve No Access      Park  Brooklyn
# 95  Spring Creek Park Gateway National Recreation ...      Park    Queens

# %% [markdown]
# ## Step 4: Slice the DataFrame to include the arrive airport and first location

# %%
first_location = ['John F. Kennedy International Airport','Juniper Valley Park']
first_andnext =  ['John F. Kennedy International Airport','Juniper Valley Park', 'High Rock Park' ]

# %%
# Create a DataFrame with the arriving Airport and the first location you will visit

arrival_and_first_location = places_of_interest_cool.loc[places_of_interest_cool['Name'].isin(first_location)]

# %%
arrival_and_first_location
# Out:
#     Id  Longitude   Latitude                                   Name  \
# 49  49 -73.879632  40.720353                    Juniper Valley Park
# 85  48 -73.785999  40.648068  John F. Kennedy International Airport
#
#                 PlaceType Borough
# 49                   Park  Queens
# 85  International Airport  Queens

# %%
# Plot the arriving airport and the first location

show_up = px.scatter_mapbox(
    arrival_and_first_location,
    lat = 'Latitude',
    lon = 'Longitude',
    color = 'Name',
)

# Show the plot
# YOUR CODE HERE
show_up

# %% [markdown]
# ## Step 5: Plot the route between your first, second and thrid locations.

# %%
# Plot the route between the first second and third locations
after_chill = places_of_interest_cool.loc[places_of_interest_cool['Name'].isin(first_andnext)] 
after_chill
# Out:
#     Id  Longitude   Latitude                                   Name  \
# 49  49 -73.879632  40.720353                    Juniper Valley Park
# 85  48 -73.785999  40.648068  John F. Kennedy International Airport
# 89  43 -74.114920  40.590435                         High Rock Park
#
#                 PlaceType        Borough
# 49                   Park         Queens
# 85  International Airport         Queens
# 89                   Park  Staten Island

# %%
trip_breakdown =  ['Juniper Valley Park', 'High Rock Park', 'Times Square']

# %%
after_chill_then = places_of_interest_cool.loc[places_of_interest_cool['Name'].isin(trip_breakdown)]

# %%
ny_trip = px.scatter_mapbox(
    after_chill_then,
    lat = 'Latitude',
    lon = 'Longitude',
    color = 'Name',
)


# Create the plot including your first, second and third locations
#second_route = # YOUR CODE HERE

# Show the Plot
# YOUR CODE HERE
ny_trip

# %% [markdown]
# ## Step 6: Plot the route between your third, fourth, and fifth locations.

# %%
first_andnext =  ['John F. Kennedy International Airport','Juniper Valley Park', 'High Rock Park' ]

# %%
trip_breakdown_four =  ['John F. Kennedy International Airport','Juniper Valley Park','High Rock Park', 'Times Square', 'Botanic Garden']

# %%
after_chill_then_later = places_of_interest_cool.loc[places_of_interest_cool['Name'].isin(trip_breakdown_four)]

# %%
## Step 5: Plot the route between your third, fourth, and fifth locations.
third_fourth_fifth_locations = px.scatter_mapbox(
    after_chill_then_later,
    lat = 'Latitude',
    lon = 'Longitude',
    color = 'Name',
)




# Create the plot including your third, fourth and fifth locations
third_fourth_fifth_locations

# Show the Plot
# YOUR CODE HERE

# %% [markdown]
# ## Step 7: Plot all the stops in your excursion

# %%
# Plot course for all of the stops in your excursion, including the airport
all_stops = # YOUR CODE HERE

# Create the plot that shows all of you stops
plot_all_stops = # YOUR CODE HERE

# Show the Plot
# YOUR CODE HERE

# %% [markdown]
# **Question** Given the location of the stops on your excursion, what is the order in which you should visit them to get you back to the airport most efficiently?
#
# **Answer** # YOUR ANSWER HERE

# %%
feels = (third_fourth_fifth_locations + ny_trip)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-42ea920775c5> in <module>
# ----> 1 feels = (third_fourth_fifth_locations + ny_trip)
#
# TypeError: unsupported operand type(s) for +: 'Figure' and 'Figure'
