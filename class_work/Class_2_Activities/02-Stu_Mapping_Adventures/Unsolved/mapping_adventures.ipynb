# %% [markdown]
# # Mapping Adventures

# %% [markdown]
# It's time to take a break from your day job and plan an adventure!
#
# Use **Plotly Express** and the **Mapbox API** to create a series of geographical plots that will visualize each area of interest within the city.

# %% [markdown]
# ## Import the required libraries and dependencies

# %%
import pandas as pd
import plotly.express as px
import os
from pathlib import Path
from dotenv import load_dotenv

# %% [markdown]
# ## Step 1: Create a .env file to hold your Mapbox API Access Token

# %% [markdown]
# ## Step 2: Read in the Mapbox API access token using the `os.getenv` function. Use the function provided to confirm that the token is available for use in the program. Finally, set your Mapbox API access token as the parameter in the `px.set_mapbox_access_token` function.

# %%
# Set up API credentials
# Read the Mapbox API access token
# YOUR CODE HERE
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 1
# True

# %%
map_box_api_access_token = os.getenv("MAPBOX_API_ACCESS_TOKEN")

# %%
type(map_box_api_access_token)
# Out:
# str

# %%
# Confirm that the mapbox_api_access_token is available
if not map_box_api_access_token:
    print("Error with the Mapbox API access token. Check the .env file.")

# %%
# Set the Mapbox API access token
# YOUR CODE HERE
px.set_mapbox_access_token(map_box_api_access_token)

# %% [markdown]
# ## Step 3: Read in the `nyc_places_interest.csv` file from the Resources folder into a Pandas DataFrame. Drop any rows that contain missing data or NaN values.

# %%
# Read the the ny_places_interest.csv file into a DataFrame
places_of_interest = pd.read_csv(
    Path('../Resources/nyc_places_interest.csv'))

# Review the DataFrame
# YOUR CODE HERE

display(places_of_interest.head())
# Out:
#    Id  Longitude   Latitude                Name PlaceType Borough
# 0  90 -73.888958  40.896210  Van Cortlandt Park      Park   Bronx
# 1  95 -73.871651  40.889879   Woodlawn Cemetery  Cemetery   Bronx
# 2  81 -73.838642  40.886965    Seton Falls Park      Park   Bronx
# 3  69 -73.809802  40.877986     Pelham Bay Park      Park   Bronx
# 4   8 -73.878308  40.864424    Botanical Garden    Garden   Bronx

# %%
display(places_of_interest.tail())
# Out:
#     Id  Longitude   Latitude  \
# 91  80 -73.898472  40.764449
# 92  75 -73.916829  40.892306
# 93  31 -73.862714  40.699448
# 94  87 -73.865019  40.645828
# 95  86 -73.844211  40.646316
#
#                                                  Name PlaceType   Borough
# 91                           Saint Michael's Cemetery  Cemetery    Queens
# 92                                     Riverdale Park      Park     Bronx
# 93                            Forest Park Golf Course       NaN    Queens
# 94               Spring Creek Park Preserve No Access      Park  Brooklyn
# 95  Spring Creek Park Gateway National Recreation ...      Park    Queens

# %% [markdown]
# ## Plot the NYC Places of Interest

# %% [markdown]
# ### Step 4: Plot All Places of Interest by Name

# %%
# Plot all of the NYC places of interest
# Set the color parameter to Name
#places_of_interest_by_name = px.scatter_mapbox(
  places_of_interest,
    lat ="Latitude",
    lon ="Longitude",
    color ="Name",
    zoom =5 
)

# Show the plot
# YOUR CODE HERE
places_of_interest_by_name.show()
# Out:
#   File "<ipython-input-42-5834be20c01f>", line 4
#     places_of_interest,
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Step 5: Plot All Places of Interest by Place Type

# %%
# Set the color parameter to Borough
dip_shti = places_of_interest_by_=px.scatter_mapbox(
    places_of_interest,
    lat = "Latitude",
    lon = "Longitude",
    color = "Borough",
    zoom = 8,
    title="NYC places of interest"
)

# %%
dip_shti.show()

# %% [markdown]
# ### Step 6: Plot All Places of Interest by Borough

# %%
# Plot all of the NYC places of interest
# Set the color parameter to PlaceType
places_of_interest_by_place_type = px.scatter_mapbox(
    places_of_interest,
    lat="Latitude",
    lon="Longitude",
    color="Id", 
)

# Show the plot
places_of_interest_by_place_type.show()

# %% [markdown]
# ### Step 7: Plot Parks of Interest

# %%
# Create a DataFrame that slices the places_of_intereset DataFrame to include only parks
parks = places_of_interest.loc[places_of_interest['PlaceType'] == 'Park']

# %%
parks.head()
# Out:
#    Id  Longitude   Latitude                Name PlaceType Borough
# 0  90 -73.888958  40.896210  Van Cortlandt Park      Park   Bronx
# 2  81 -73.838642  40.886965    Seton Falls Park      Park   Bronx
# 3  69 -73.809802  40.877986     Pelham Bay Park      Park   Bronx
# 5   9 -73.876261  40.855522          Bronx Park      Park   Bronx
# 7  27 -73.832846  40.814343    Ferry Point Park      Park   Bronx

# %%
# Plot all of the parks in NYC
# What column should color be set equal to?
parks_of_interest = px.scatter_mapbox(
    parks,
    lat = 'Latitude',
    lon = 'Longitude',
    color = 'PlaceType'


)

# Show the plot
# YOUR CODE HERE
parks_of_interest

# %% [markdown]
# ### Step 8: Plot Gardens of Interest

# %%
# Create a DataFrame that slices the places_of_intereset DataFrame to include only gardens

gardens = places_of_interest.loc[places_of_interest['PlaceType'] == 'Garden']

# %%
display(gardens)
# Out:
#     Id  Longitude   Latitude              Name PlaceType   Borough
# 4    8 -73.878308  40.864424  Botanical Garden    Garden     Bronx
# 27   7 -73.966125  40.669937    Botanic Garden    Garden  Brooklyn

# %%
# Plot all of the gardens in NYC

gardens_of_interest = px.scatter_mapbox(
   
    gardens,
    
    lat = 'Latitude',
    
    lon = 'Longitude',
    
    color = 'PlaceType'


)

# %%
# Show the plot
# YOUR CODE HERE
gardens_of_interest

# %% [markdown]
# # Plot all of the gardens in NYC
#
# gardens_of_interest = px.scatter_mapbox(
#
#     gardens,
#
#     lat = 'Latitude',
#
#     lon = 'Longitude',
#
#     color = 'PlaceType'
#
#
# )### Step 9: Plot Squares of Interest

# %%
# Create a DataFrame that slices the places_of_intereset DataFrame to include only squares

squares = places_of_interest.loc[places_of_interest['PlaceType'] == 'Square']

squares
# Out:
#     Id  Longitude   Latitude            Name PlaceType    Borough
# 21  88 -73.981794  40.758021    Times Square    Square  Manhattan
# 22  56 -73.988067  40.742181  Madison Square    Square  Manhattan
# 23  89 -73.990380  40.735960    Union Square    Square  Manhattan

# %%
# Plot all of the gardens in NYC
squares_of_interst = px.scatter_mapbox(
    
    squares,
     
    lat = 'Latitude',
    
    lon = 'Longitude',
    
    color = 'PlaceType'


)

# Show the plot
# YOUR CODE HERE

squares_of_interst

# %% [markdown]
# ### Step 10: Chllenge - Pick two place of interest and plot them both on a the map

# %%
inthere_likeswim_wear = ["Riverdale Park", 'Forest Park Golf Course']

# %%
# Slice the name of two places from the places_of_interest DataFrame
# Use the Pandas isin function to reference the specific name of a location
two_places = places_of_interest.loc[places_of_interest['Name'].isin(inthere_likeswim_ware)] 

# Create the Plot for just the two places
two_places_route = px.scatter_mapbox(
    two_places,
    lat = 'Latitude',
    lon = 'Longitude',
    color = "Name")

# Show the plot
# YOUR CODE HERE
two_places_route

# %%
df.isin([0, 2])

# %%
places_of_interest_by_name = px.scatter_geo(
    places_of_interest,
    color = 'Name' 
)

# Show the plot
places_of_interest_by_name
